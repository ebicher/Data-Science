# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('Welcome.csv', encoding = "latin1")

# %%
df.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# ...

# %%
df.tail()
# Out:
#                             PMID/PMCID                      Publisher  \
# 2122                           2901593          Wolters Kluwer Health
# 2123                           3748854         Wolters Kluwer Health
# 2124                           3785148         Wolters Kluwer Health
# 2125          PMCID:\n    PMC3647051\n  Wolters Kluwer N.V./Lippinott
# 2126  PMID: 23846567  (Epub July 2013)                Wolters Kluwers
#
#                                         Journal title  \
# 2122                             Circulation Research
# 2123                                             AIDS
# 2124                             Pediatr Infect Dis J
# 2125                                             AIDS
# 2126  Journal of Acquired Immune Deficiency Syndromes
#
#                                           Article title  \
# 2122  Mechanistic Links Between Na+ Channel (SCN5A) ...
# 2123  Evaluation of an empiric risk screening score ...
# ...

# %% [markdown]
# Determine the five most common journals and the total articles for each. Next, calculate the mean, median, and standard deviation of the open-access cost per article for each journal

# %%
df.rename(columns={'COST (£) charged to Wellcome (inc VAT when charged)':'Cost'}, inplace = True)

# %%
df.tail()
# Out:
#                             PMID/PMCID                      Publisher  \
# 2122                           2901593          Wolters Kluwer Health
# 2123                           3748854         Wolters Kluwer Health
# 2124                           3785148         Wolters Kluwer Health
# 2125          PMCID:\n    PMC3647051\n  Wolters Kluwer N.V./Lippinott
# 2126  PMID: 23846567  (Epub July 2013)                Wolters Kluwers
#
#                                         Journal title  \
# 2122                             Circulation Research
# 2123                                             AIDS
# 2124                             Pediatr Infect Dis J
# 2125                                             AIDS
# 2126  Journal of Acquired Immune Deficiency Syndromes
#
#                                           Article title      Cost
# 2122  Mechanistic Links Between Na+ Channel (SCN5A) ...  £1334.15
# 2123  Evaluation of an empiric risk screening score ...  £1834.77
# ...

# %%
df=(df.replace('[\£,)]','', regex=True ))

# %%
df.tail()
# Out:
#                            PMID/PMCID                      Publisher  \
# 2122                          2901593          Wolters Kluwer Health
# 2123                          3748854         Wolters Kluwer Health
# 2124                          3785148         Wolters Kluwer Health
# 2125         PMCID:\n    PMC3647051\n  Wolters Kluwer N.V./Lippinott
# 2126  PMID: 23846567  (Epub July 2013                Wolters Kluwers
#
#                                         Journal title  \
# 2122                             Circulation Research
# 2123                                             AIDS
# 2124                             Pediatr Infect Dis J
# 2125                                             AIDS
# 2126  Journal of Acquired Immune Deficiency Syndromes
#
#                                           Article title     Cost
# 2122  Mechanistic Links Between Na+ Channel (SCN5A M...  1334.15
# 2123  Evaluation of an empiric risk screening score ...  1834.77
# ...

# %%
df['Journal title'] = df['Journal title'].str.lower()

# %%
df.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  psychological medicine
# 1             PMC3679557       ACS       biomacromolecules
# 2  23043264  PMC3506128        ACS              j med chem
# 3    23438330 PMC3646402       ACS              j med chem
# 4   23438216 PMC3601604        ACS              j org chem
#
#                                        Article title     Cost
# 0  Reduced parahippocampal cortical thickness in ...     0.00
# 1  Structural characterization of a Model Gram-ne...  2381.04
# 2  Fumaroylamino-45-epoxymorphinans and related o...   642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   669.64
# 4  Regioselective opening of myo-inositol orthoes...   685.88

# %%
df.groupby('Journal title').count()
# Out:
#                                                     PMID/PMCID  Publisher  \
# Journal title
# academy of nutrition and dietetics                           1          1
# acs chemical biology                                         4          5
# acs chemical neuroscience                                    1          1
# acs nano                                                     2          2
# acta crystallographica section d                             1          1
# acta crystallographica section d  biological cr...           1          1
# acta crystallographica section d: biological cr...           1          1
# acta crystallographica section f: structural bi...           2          2
# acta crystallography d                                       1          1
# acta d                                                       1          1
# acta dermato venereologica                                   1          1
# ...

# %%
df['Journal title']=(df['Journal title'].replace('(of)','', regex=True ))
df['Journal title']=(df['Journal title'].replace('(and)','', regex=True ))
df['Journal title']=(df['Journal title'].replace('(the)','', regex=True ))

# %%
df['Journal title']
# Out:
# 0                                  psychological medicine
# 1                                       biomacromolecules
# 2                                              j med chem
# 3                                              j med chem
# 4                                              j org chem
# 5                            journal  medicinal chemistry
# 6                              journal  proteome research
# 7                                               mol pharm
# 8                                    acs chemical biology
# 9                                    acs chemical biology
# 10                journal  chemical information  modeling
# 11                           journal  medicinal chemistry
# 12                           journal  medicinal chemistry
# 13                                           biochemistry
# 14                           journal  medicinal chemistry
# 15                                       gastroenterology
# ...

# %%
df.to_csv('newlist1.csv')

# %%
df['Journal title']=(df['Journal title'].replace(' ','', regex=True ))

# %%
df['Journal title']
# Out:
# 0                               psychologicalmedicine
# 1                                   biomacromolecules
# 2                                            jmedchem
# 3                                            jmedchem
# 4                                            jorgchem
# 5                           journalmedicinalchemistry
# 6                             journalproteomeresearch
# 7                                            molpharm
# 8                                  acschemicalbiology
# 9                                  acschemicalbiology
# 10                 journalchemicalinformationmodeling
# 11                          journalmedicinalchemistry
# 12                          journalmedicinalchemistry
# 13                                       biochemistry
# 14                          journalmedicinalchemistry
# 15                                   gastroenterology
# 16                         journalbiologicalchemistry
# ...

# %%
df=(df.replace('[$/)]','', regex=True ))

# %%
df['Journal title']=(df['Journal title'].replace('[1]','one', regex=True ))

# %%
df
# Out:
#                            PMID/PMCID  \
# 0                                 NaN
# 1                          PMC3679557
# 2               23043264  PMC3506128
# 3                 23438330 PMC3646402
# 4                23438216 PMC3601604
# 5                          PMC3579457
# 6                          PMC3709265
# 7                23057412 PMC3495574
# 8                   PMCID: PMC3780468
# 9                   PMCID: PMC3621575
# 10                  PMCID: PMC3739413
# 11                  PMCID: PMC3530961
# 12                  PMCID: PMC3624797
# 13                         PMC3413243
# 14                         PMC3694353
# 15                         PMC3572711
# 16                           22610094
# 17                  PMCID: PMC3586974
# 18       23455506  PMCID: PMC3607399
# 19         PMID: 24015914 PMC3833349
# 20                      : PMC3805332
# 21                                NaN
# 22           PMCID:\n    PMC3656742\n
# 23                     PMCID: 3584654
# ...

# %%
df.to_csv('newlist1.csv')
