# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from __future__ import print_function
from scipy.ndimage import convolve
from sklearn import linear_model, datasets, metrics
from sklearn.model_selection import train_test_split
from sklearn.neural_network import BernoulliRBM
from sklearn.pipeline import Pipeline
from sklearn.base import clone

# %%
# open notebook with this :: jupyter notebook --NotebookApp.iopub_data_rate_limit=10000000000

# %%
from PIL import Image
im = Image.open("../../../Data/Simpsons/Original/bart_simpson/pic_0000.jpg")

#print(list(np.asarray(im)))

# %%
im.size
# Out:
# (320, 480)

# %%
#im2 = im.convert('1')

# %%
im.show()

# %%
pixels = np.asarray(im)

# %%
pixels.shape

# %%
im2 = im.convert('1')
pixels2 = np.asarray(im2)

# %%
plt.imshow(pixels)

# %%
datatest = {'data':pixels, 'char':'Bart'}

# %%
datatest.data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-ea2ca4180f3d> in <module>()
# ----> 1 datatest.data
#
# AttributeError: 'dict' object has no attribute 'data'
