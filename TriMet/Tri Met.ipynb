# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dftrip = pd.read_csv('trips_day.csv')

# %%
dfevent = pd.read_csv('events_day.csv')

# %%
merged = pd.merge(dftrip, dfevent, on=['tripID', 'vehicle_id'])

# %%
merged
# Out:
#         tripID  vehicle_id  blockID  direction garage  routeNumber  bearing  \
# 0      7126389         115     9040          0   ELMO           90       36
# 1      7126389         201     9040          0   ELMO           90       36
# 2      7126389         209     9040          0   ELMO           90      103
# 3      7126389         209     9040          0   ELMO           90       21
# 4      7126389         209     9040          0   ELMO           90       57
# 5      7126389         209     9040          0   ELMO           90       91
# 6      7126389         209     9040          0   ELMO           90       91
# 7      7126389         209     9040          0   ELMO           90      108
# 8      7126389         209     9040          0   ELMO           90      124
# 9      7126389         209     9040          0   ELMO           90       53
# 10     7126389         209     9040          0   ELMO           90      101
# ...

# %%
checky = merged.groupby('signMessageLong').mean()

# %%
checky
# Out:
#                                                    tripID  vehicle_id  \
# signMessageLong
# MAX  Blue Line to City Center                7.127500e+06  315.292576
# MAX  Blue Line to Elmonica/170th             7.127625e+06  228.492711
# MAX  Blue Line to Gateway TC                 7.127348e+06  292.628440
# MAX  Blue Line to Gresham                    7.127295e+06  287.916495
# MAX  Blue Line to Hillsboro                  7.127669e+06  281.534978
# MAX  Blue Line to Rose Qtr                   7.127563e+06  404.229730
# MAX  Blue Line to Ruby Junction/E 197th Ave  7.127267e+06  308.793535
# MAX  Blue Line to Willow Creek/SW 185th Ave  7.127661e+06  231.099526
# MAX  Green Line to City Center/PSU           7.129535e+06  336.454245
# MAX  Green Line to Clackamas Town Center     7.129322e+06  334.196338
# MAX  Green Line to Gateway TC                7.129454e+06  294.377119
# MAX  Orange Line to City Center/Expo Center  7.130081e+06  360.208424
# ...

# %%
plt.hist(checky['delay'], color='purple')
plt.ylabel('Amount')
plt.xlabel('Delay Time (sec)')
plt.title('Delay Distribution')
# Out:
# Text(0.5,1,'Delay Distribution')

# %%
routetry = merged[merged['routeNumber'] == 90]
routetry
# Out:
#        tripID  vehicle_id  blockID  direction garage  routeNumber  bearing  \
# 0     7126389         115     9040          0   ELMO           90       36
# 1     7126389         201     9040          0   ELMO           90       36
# 2     7126389         209     9040          0   ELMO           90      103
# 3     7126389         209     9040          0   ELMO           90       21
# 4     7126389         209     9040          0   ELMO           90       57
# 5     7126389         209     9040          0   ELMO           90       91
# 6     7126389         209     9040          0   ELMO           90       91
# 7     7126389         209     9040          0   ELMO           90      108
# 8     7126389         209     9040          0   ELMO           90      124
# 9     7126389         209     9040          0   ELMO           90       53
# 10    7126389         209     9040          0   ELMO           90      101
# ...

# %%
routetry = routetry[routetry['signMessageLong']=='MAX Red Line to Airport']

# %%
routetry
# Out:
# Empty DataFrame
# Columns: [tripID, vehicle_id, blockID, direction, garage, routeNumber, bearing, delay, timestamp, lastLocID, lastStopSeq, nextLocID, nextStopSeq, signMessageLong, vehicle_location_longitude, vehicle_location_latitude]
# Index: []

# %%
numberofstops['blockID'].mean()
# Out:
#                                           tripID  vehicle_id  blockID  \
# signMessageLong
# MAX  Red Line to Airport                    3292        3292     3292
# MAX  Red Line to City Center & Beaverton    2694        2694     2694
#
#                                           direction  garage  routeNumber  \
# signMessageLong
# MAX  Red Line to Airport                       3292    3292         3292
# MAX  Red Line to City Center & Beaverton       2694    2694         2694
#
#                                           bearing  delay  timestamp  \
# signMessageLong
# MAX  Red Line to Airport                     3292   3292       3292
# MAX  Red Line to City Center & Beaverton     2694   2694       2694
#
#                                           lastLocID  lastStopSeq  nextLocID  \
# signMessageLong
# MAX  Red Line to Airport                       3292         3292       3292
# MAX  Red Line to City Center & Beaverton       2694         2694       2694
#
# ...

# %%
df3 = numberofstops[numberofstops['blockID'] < 42]

# %%
df3
# Out:
#          vehicle_id  blockID  direction  garage  routeNumber  bearing  delay  \
# tripID
# 7126389          40       40         40      40           40       40     40
# 7126425          35       35         35      35           35       35     35
# 7126436          21       21         21      21           21       21     21
# 7126445          21       21         21      21           21       21     21
# 7126589          22       22         22      22           22       22     22
# 7126590          33       33         33      33           33       33     33
# 7126595          40       40         40      40           40       40     40
# 7126596          10       10         10      10           10       10     10
# 7126598          40       40         40      40           40       40     40
# 7126600          10       10         10      10           10       10     10
# 7126606          40       40         40      40           40       40     40
# ...

# %%
df3 = df3.reset_index()

# %%
listofIDs = list(df3['tripID'])

listofIDs[1]
# Out:
# 7126425

# %%
routetry.set_index('tripID')
# Out:
#          vehicle_id  blockID  direction garage  routeNumber  bearing  delay  \
# tripID
# 7126389         115     9040          0   ELMO           90       36   -154
# 7126389         201     9040          0   ELMO           90       36   -154
# 7126389         209     9040          0   ELMO           90      103     52
# 7126389         209     9040          0   ELMO           90       21     30
# 7126389         209     9040          0   ELMO           90       57     27
# 7126389         209     9040          0   ELMO           90       91      5
# 7126389         209     9040          0   ELMO           90       91    -33
# 7126389         209     9040          0   ELMO           90      108     90
# 7126389         209     9040          0   ELMO           90      124     67
# 7126389         209     9040          0   ELMO           90       53     37
# 7126389         209     9040          0   ELMO           90      101     60
# ...

# %%
result.boxplot(column = 'delay', by = 'color')
plt.xticks(rotation=90)
plt.xlabel('Route Color')
plt.ylabel('Delay Amount')
