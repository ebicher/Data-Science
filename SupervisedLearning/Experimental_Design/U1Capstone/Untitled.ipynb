# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
db = pd.read_csv('listings.csv')

# %%
db.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0      6      https://www.airbnb.com/rooms/6  20180816121151   2018-08-16
# 1   5570   https://www.airbnb.com/rooms/5570  20180816121151   2018-08-16
# 2   8095   https://www.airbnb.com/rooms/8095  20180816121151   2018-08-16
# 3  14668  https://www.airbnb.com/rooms/14668  20180816121151   2018-08-16
# 4  38245  https://www.airbnb.com/rooms/38245  20180816121151   2018-08-16
#
#                                              name  \
# 0  Large Craftsmen w/ yard ~ Perfect for families
# 1                   Ocean front condo on the sand
# 2                            Sunset Cliffs Studio
# 3                Close to Everything in San Diego
# 4               Downstairs Den: Point Loma by NTC
#
#                                              summary  \
# 0  Our Beautiful Craftsmen house has all the mode...
# 1  Missionbeachretreat.   Great Ocean Front Condo...
# ...

# %%
db=(db.replace('[\$,)]','', regex=True ))

# %%
db['price'].astype(float).describe()
# Out:
# count    11726.000000
# mean       216.610950
# std        296.286212
# min          0.000000
# 25%         80.000000
# 50%        135.000000
# 75%        250.000000
# max      10000.000000
# Name: price, dtype: float64
